# %%
from typing import TypedDict

class PortfolioState(TypedDict):
    amount_usd: float
    total_usd: float
    total_inar: float

# %%
def calc_total(state: PortfolioState) -> PortfolioState:
    state["total_inar"] = state["amount_usd"] * 1.08
    return state

def convert_to_inr(state: PortfolioState) -> PortfolioState:
    state["total_inar"] = state["amount_usd"] * 85
    return

# %%
from langgraph.graph import StateGraph, START, END
builder = StateGraph(PortfolioState)

builder.add_node("calc_total", calc_total)
builder.add_node("convert_to_inr", convert_to_inr)

builder.add_edge(START, "calc_total")
builder.add_edge("calc_total", "convert_to_inr")
builder.add_edge("convert_to_inr", END)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 from langgraph.graph import StateGraph, START, END
# ----> 2 builder = StateGraph(PortfolioState)
#       4 builder.add_node("calc_total", calc_total)
#       5 builder.add_node("convert_to_inr", convert_to_inr)
#
# NameError: name 'PortfolioState' is not defined
